# %% [markdown]
# <a href="https://colab.research.google.com/github/Lins0104/Talento-Tech/blob/main/Taller_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #INTRODUCCIÓN
# Usaré esta notebook para proporcionar una introducción a SQL, lenguaje imprescindible para todo analista de datos.
#
# Los sistemas gestores de bases de datos interpretan consultas escritas en lenguaje SQL, y así es como interactuamos y obtenemos datos de las bases de datos y aplicaciones.
#
# SQL significa Structured Query Language (Lenguaje de consulta estructurado) SQL permite acceder y manipular bases de datos SQL es una herramienta simple para el análisis avanzado de datos SQL no se usa sólo para manipular datos, sino también para administrar la misma base de datos, crear y modificar el diseño de objetos de la base de datos, como tablas. El elemento de SQL que se usa para crear y modificar objetos de base de datos se denomina lenguaje de definición de datos (DDL). Este curso no trata DDL.
#
# En esta notebook veremos cómo trabajar/manipular tablas. Aprenderemos a usar SQL para interactuar con una base de datos de fútbol europeo y generar información interesante con sus datos.
#
# La base de datos utilizada, pueder ser encontrada aquí
#
# Este ejercicio esta basado en el repositorio de (https://www.kaggle.com/code/gustavojaramillo/data-analysis-using-sql-espa-ol)

# %%
# Importar librerías
import pandas as pd
import sqlite3 # SQLite

# %%
# Lectura
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Define the path to your database file
path = '/content/drive/MyDrive/Colab Notebooks/TallerdeSQL/'  # Remove 'database.sqlite' from the path
database = path + 'database.sqlite'  # Construct the full path correctly
conn = sqlite3.connect(database)
print ("Conexión exitosa")

print (database)

tables = pd.read_sql("SELECT * FROM sqlite_master WHERE type= 'table';", conn)
print(tables)
# Out:
# Conexión exitosa
# /content/drive/MyDrive/Colab Notebooks/TallerdeSQL/database.sqlite
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# 7  CREATE TABLE `Team_Attributes` (\n\t`id`\tINTE...

# %% [markdown]
# ##Sentencia SELECT
# Listar paises

# %%
query = "SELECT * FROM 'Country';"
countries = pd.read_sql(query, conn)
countries
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %% [markdown]
# Listar ligas del futbol europeo

# %%
#Consulta todas las ligas del futbol europeo
query = """SELECT *
            FROM League; """

#No modificar lo siguiente:
leagues = pd.read_sql(query, conn)
leagues
# Out:
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %% [markdown]
# Listar los jugadores del fútbol europeo

# %%
# Colsultar todos los jugadores del futbol europeo
query = """SELECT* FROM Player;"""

#No modificar lo siguiente:
players = pd.read_sql(query, conn)
players
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight
# 0      1992-02-29 00:00:00  182.88     187
# 1      1989-12-15 00:00:00  170.18     146
# 2      1991-05-13 00:00:00  170.18     163
# 3      1982-05-08 00:00:00  182.88     198
# 4      1979-11-08 00:00:00  182.88     154
# ...                    ...     ...     ...
# 11055  1979-04-03 00:00:00  182.88     168
# 11056  1986-12-18 00:00:00  182.88     176
# 11057  1979-04-29 00:00:00  180.34     154
# 11058  1981-10-06 00:00:00  185.42     172
# 11059  1982-06-05 00:00:00  180.34     176
#
# [11060 rows x 7 columns]

# %% [markdown]
# Sentencia SELECT DISTINCT

# %%
#Consulta de solo los jugadores únicos de la tabla Player
query = """SELECT DISTINCT player_name FROM Player; """

#Creo una variable players_distinct que almacene los jugadores únicos
players_distinct = pd.read_sql(query, conn)
players_distinct
# Out:
#                player_name
# 0       Aaron Appindangoye
# 1          Aaron Cresswell
# 2              Aaron Doran
# 3            Aaron Galindo
# 4             Aaron Hughes
# ...                    ...
# 10843       Zoumana Camara
# 10844         Zsolt Laczko
# 10845            Zsolt Low
# 10846  Zurab Khizanishvili
# 10847   Zvjezdan Misimovic
#
# [10848 rows x 1 columns]

# %% [markdown]
# Listar las temporadas jugadas de esta Base de Datos

# %%
query = """SELECT DISTINCT season
           FROM Match;"""

seasons = pd.read_sql(query, conn)
seasons

#Las temporadas de análisis son 8, comprendidas entre los años 2008 y 2016
# Out:
#       season
# 0  2008/2009
# 1  2009/2010
# 2  2010/2011
# 3  2011/2012
# 4  2012/2013
# 5  2013/2014
# 6  2014/2015
# 7  2015/2016

# %% [markdown]
# Listar sólo tasas diferentes de valoración general de los jugadores.

# %%
query = """SELECT DISTINCT overall_rating
           FROM Player_Attributes;"""

overall_rating = pd.read_sql(query, conn)
overall_rating
# Out:
#     overall_rating
# 0             67.0
# 1             62.0
# 2             61.0
# 3             74.0
# 4             73.0
# ..             ...
# 57            33.0
# 58            36.0
# 59            37.0
# 60            35.0
# 61            94.0
#
# [62 rows x 1 columns]

# %% [markdown]
# ##3 Sentencia LIMIT
# Listar 15 jugadores de la base de datos del fútbol europeo

# %%
query = """SELECT id, player_name, birthday, height, weight
           FROM Player
           LIMIT 15;"""

jugadores = pd.read_sql(query, conn)
jugadores
# Out:
#     id         player_name             birthday  height  weight
# 0    1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1    2     Aaron Cresswell  1989-12-15 00:00:00  170.18     146
# 2    3         Aaron Doran  1991-05-13 00:00:00  170.18     163
# 3    4       Aaron Galindo  1982-05-08 00:00:00  182.88     198
# 4    5        Aaron Hughes  1979-11-08 00:00:00  182.88     154
# 5    6          Aaron Hunt  1986-09-04 00:00:00  182.88     161
# 6    7          Aaron Kuhl  1996-01-30 00:00:00  172.72     146
# 7    8        Aaron Lennon  1987-04-16 00:00:00  165.10     139
# 8    9        Aaron Lennox  1993-02-19 00:00:00  190.50     181
# 9   10       Aaron Meijers  1987-10-28 00:00:00  175.26     170
# 10  11       Aaron Mokoena  1980-11-25 00:00:00  182.88     181
# 11  12          Aaron Mooy  1990-09-15 00:00:00  175.26     150
# 12  13      Aaron Muirhead  1990-08-30 00:00:00  187.96     168
# 13  14        Aaron Niguez  1989-04-26 00:00:00  170.18     143
# 14  15        Aaron Ramsey  1990-12-26 00:00:00  177.80     154

# %% [markdown]
# Listar 25 equipos del fútbol europeo

# %%
query = """SELECT id, team_long_name
           FROM Team
           LIMIT 25;"""

equipos = pd.read_sql(query, conn)
equipos
# Out:
#       id        team_long_name
# 0      1              KRC Genk
# 1      2          Beerschot AC
# 2      3      SV Zulte-Waregem
# 3      4      Sporting Lokeren
# 4      5     KSV Cercle Brugge
# 5      6        RSC Anderlecht
# 6      7              KAA Gent
# 7      8             RAEC Mons
# 8      9         FCV Dender EH
# 9     10     Standard de Liège
# 10    11           KV Mechelen
# 11    12        Club Brugge KV
# 12    13         KSV Roeselare
# 13    14           KV Kortrijk
# 14    15                Tubize
# 15    16  Royal Excel Mouscron
# 16    17          KVC Westerlo
# 17    18    Sporting Charleroi
# 18   614     Sint-Truidense VV
# 19  1034             Lierse SK
# 20  1042             KAS Eupen
# 21  1513   Oud-Heverlee Leuven
# 22  2004      Waasland-Beveren
# 23  2476           KV Oostende
# 24  2510  Royal Excel Mouscron

# %% [markdown]
# ##4 Funciones agregativas/ Métricas
#
#
# *  SUM() | Sumatoria total de una columna tipo numérica.
# *  COUNT() | Devuelve la cantidad de filas
# *   COUNT(DISTINCT) | Devuelve la cantidad de filas distintas o diferentes.
#
# *   AVG() | Promedia los valores de una columna tipo numérica.
# *   MIN() | Menor valor dentro de la columna especificada.
# *   MAX() | Mayor valor dentro de la columna especificada.
#
#
#
# ¿Cuántos países diferentes están almacenados en la tabla Country?

# %%
query = """ SELECT COUNT(DISTINCT name)
            FROM Country;"""

count_countries = pd.read_sql(query, conn)
count_countries
# Out:
#    COUNT(DISTINCT name)
# 0                    11

# %% [markdown]
# Traer el número de etapas jugadas de la tabla Match

# %%
query = """SELECT COUNT(DISTINCT stage)
           FROM Match;"""

countdis_stages = pd.read_sql(query, conn)
countdis_stages
# Out:
#    COUNT(DISTINCT stage)
# 0                     38

# %% [markdown]
# Traer la suma de goles hechos por los equipos visitantes de la tabla Match

# %%
query = """SELECT SUM(away_team_goal) FROM Match;"""

sum_away_team_goal = pd.read_sql(query, conn)
sum_away_team_goal
# Out:
#    SUM(away_team_goal)
# 0                30160

# %% [markdown]
# Traer el promedio de goles hechos por los equipos locales y el promedio de goles hechos por los visitantes de la tabla Match

# %%
query = """SELECT AVG(home_team_goal), AVG(away_team_goal)
           FROM Match;"""

avg_home_team_goal = pd.read_sql(query, conn)
avg_home_team_goal
# Out:
#    AVG(home_team_goal)  AVG(away_team_goal)
# 0             1.544594             1.160938

# %% [markdown]
# Traer la máxima cantidad de goles que un equipo visitante anotó en los juegos de la tabla Match

# %%
query = """SELECT MAX(away_team_goal) FROM Match;"""

max_away_team_goal = pd.read_sql(query, conn)
max_away_team_goal
# Out:
#    MAX(away_team_goal)
# 0                    9

# %% [markdown]
# ##5. Operaciones matemáticas
#
# Traer el promedio de goles por partido de la tabla Match

# %%
query=""" SELECT AVG(home_team_goal + away_team_goal) FROM Match;"""

avg_goals_per_match = pd.read_sql(query, conn)
avg_goals_per_match
# Out:
#    AVG(home_team_goal + away_team_goal)
# 0                              2.705531

# %% [markdown]
# ##6. Sentencia WHERE

# %% [markdown]
# Listar los jugadores que pesan 165 libras

# %%
query="""SELECT id, player_name, birthday, height, weight FROM Player WHERE weight = 165 LIMIT 15;"""

player_weight = pd.read_sql(query, conn)
player_weight
# Out:
#      id          player_name             birthday  height  weight
# 0    27   Abdelmalek Cherrad  1981-01-14 00:00:00  185.42     165
# 1    44   Abdoulaye Doucoure  1993-01-01 00:00:00  182.88     165
# 2    46      Abdoulaye Keita  1994-01-05 00:00:00  175.26     165
# 3    49  Abdoulwahid Sissoko  1990-03-20 00:00:00  182.88     165
# 4    58   Abdullah Al Hafith  1992-12-25 00:00:00  187.96     165
# 5    62           Abel Gomez  1982-02-20 00:00:00  182.88     165
# 6    67                 Abel  1978-12-22 00:00:00  177.80     165
# 7    69         Abiola Dauda  1988-02-03 00:00:00  180.34     165
# 8    78     Abraham Paz Cruz  1979-03-14 00:00:00  177.80     165
# 9    84          Aco Stojkov  1983-04-29 00:00:00  177.80     165
# 10  110            Adam King  1995-10-11 00:00:00  180.34     165
# 11  119       Adam Matuschyk  1989-02-14 00:00:00  180.34     165
# 12  132            Adam Vass  1988-09-09 00:00:00  180.34     165
# 13  157        Adnan Januzaj  1995-02-05 00:00:00  182.88     165
# 14  169   Adrian Klepczynski  1981-04-01 00:00:00  187.96     165

# %% [markdown]
# Listar las temporadas en que un equipo visitante anotó 7 o más goles

# %%
query="""SELECT season, home_team_goal, away_team_goal FROM Match Where away_team_goal >= 7;"""

away_team_goal = pd.read_sql(query, conn)
away_team_goal
# Out:
#        season  home_team_goal  away_team_goal
# 0   2012/2013               1               7
# 1   2014/2015               1               7
# 2   2014/2015               2               7
# 3   2015/2016               0               9
# 4   2010/2011               1               8
# 5   2013/2014               0               7
# 6   2010/2011               0               7
# 7   2013/2014               0               7
# 8   2010/2011               0               8
# 9   2011/2012               0               7
# 10  2014/2015               0               8
# 11  2014/2015               2               8
# 12  2015/2016               0               8
# 13  2008/2009               1               7
# 14  2009/2010               1               7
# 15  2015/2016               0               7

# %% [markdown]
# *Operadores lógicos en WHERE*
#
#
#  *   El operador AND muestra un registro si todas las condiciones separadas por AND son VERDADERA(s).
# *   El operador OR muestra un registro si alguna de las condiciones separadas por OR es VERDADERA(s).
# *   El operador NOT muestra un registro si la(s) condición(es) NO es VERDADERA(s).

# %% [markdown]
# Traer el Id de los equipos que desarrollan un dribbling normal y su velocidad de juego es balanceada

# %%
query= """SELECT id, buildUpPlayDribblingClass, buildUpPlaySpeedClass FROM Team_Attributes WHERE buildUpPlayDribblingClass = 'Normal' AND buildUpPlaySpeedClass = 'Balanced';"""

team_attributes = pd.read_sql(query, conn)
team_attributes
# Out:
#        id buildUpPlayDribblingClass buildUpPlaySpeedClass
# 0       2                    Normal              Balanced
# 1       3                    Normal              Balanced
# 2       8                    Normal              Balanced
# 3       9                    Normal              Balanced
# 4      14                    Normal              Balanced
# ..    ...                       ...                   ...
# 382  1450                    Normal              Balanced
# 383  1451                    Normal              Balanced
# 384  1452                    Normal              Balanced
# 385  1457                    Normal              Balanced
# 386  1458                    Normal              Balanced
#
# [387 rows x 3 columns]

# %% [markdown]
# Traer el Id de los equipos que desarrollan un juego de pase largo o su velocidad de juego es rápida

# %%
query= """SELECT id, buildUpPlayPassingClass, buildUpPlaySpeedClass FROM Team_Attributes WHERE buildUpPlayPassingClass = 'Long' OR buildUpPlaySpeedClass = 'Fast';"""

team_attributes = pd.read_sql(query, conn)
team_attributes
# Out:
#        id buildUpPlayPassingClass buildUpPlaySpeedClass
# 0       4                    Long                  Fast
# 1      42                    Long              Balanced
# 2      69                   Mixed                  Fast
# 3      72                   Mixed                  Fast
# 4      77                   Mixed                  Fast
# ..    ...                     ...                   ...
# 226  1420                   Mixed                  Fast
# 227  1421                    Long                  Fast
# 228  1423                    Long                  Fast
# 229  1436                    Long              Balanced
# 230  1437                    Long              Balanced
#
# [231 rows x 3 columns]

# %% [markdown]
# Traer la tabla de países sin Bélgica

# %%
query = """SELECT id, name FROM Country WHERE name != 'Belgium';"""

country = pd.read_sql(query, conn)
country
# Out:
#       id         name
# 0   1729      England
# 1   4769       France
# 2   7809      Germany
# 3  10257        Italy
# 4  13274  Netherlands
# 5  15722       Poland
# 6  17642     Portugal
# 7  19694     Scotland
# 8  21518        Spain
# 9  24558  Switzerland

# %% [markdown]
# *Otros operadores que trabajan con la sentencia WHERE*
#
# Los siguientes operadores también pueden ser utilizados en la sentencia WHERE:
#
# *   | = | Igual
# *   | > | Mayor que
# *   | < | Menor que
# *   | >= | Mayor o igual que
# *   | <= | Menor o igual que
# *   | <> | No igual. Nota: En algunas versiones de SQL este operador puede ser escrito como !=
# *   | BETWEEN | Entre cierto rango
# *   | LIKE | Para consultar los datos basados en información parcial, se utiliza el operador LIKE en la sentencia WHERE. Busca un patrón. El patrón va antes, después o entre un par de % (wildcard). Ejemplo: LIKE 's%' busca cualquier texto que comience con 's'. LIKE '%er' busca cualquier texto que termine con 'er'. Y LIKE '%per%' busca cualquier texto que contenga 'per'.
# *   | IN | Para especificar varios valores posibles para una columna o subquery

# %% [markdown]
# Traer la tabla de países únicamente con Italia

# %%
query = """SELECT id, name FROM Country WHERE name= 'Italy';"""

country = pd.read_sql(query, conn)
country
# Out:
#       id   name
# 0  10257  Italy

# %% [markdown]
# Traer la tabla de países sin Polonia

# %%
query = """SELECT id, name FROM Country WHERE name != 'Poland';"""

country = pd.read_sql(query, conn)
country
# Out:
#       id         name
# 0      1      Belgium
# 1   1729      England
# 2   4769       France
# 3   7809      Germany
# 4  10257        Italy
# 5  13274  Netherlands
# 6  17642     Portugal
# 7  19694     Scotland
# 8  21518        Spain
# 9  24558  Switzerland

# %% [markdown]
# Listar los jugadores que pesen entre 174 y 176 libras

# %%
query= """SELECT id, player_name, birthday, height, weight FROM Player WHERE weight BETWEEN 174 AND 176 LIMIT 30;"""

player_w = pd.read_sql(query, conn)
player_w
# Out:
#      id            player_name             birthday  height  weight
# 0    17  Aaron Taylor-Sinclair  1991-04-08 00:00:00  182.88     176
# 1    34           Abdou Traore  1988-01-17 00:00:00  180.34     174
# 2    39           Abdoulaye Ba  1991-01-01 00:00:00  198.12     174
# 3    43       Abdoulaye Diallo  1992-03-30 00:00:00  187.96     174
# 4    61           Abel Aguilar  1985-01-06 00:00:00  185.42     176
# 5    68     Abella Perez Damia  1982-04-15 00:00:00  187.96     174
# 6    74       Abraham Gonzalez  1985-07-16 00:00:00  177.80     176
# 7    79          Achille Coser  1982-07-14 00:00:00  185.42     174
# 8    89             Adam Banas  1982-12-25 00:00:00  185.42     174
# 9    90            Adam Bodzek  1985-09-07 00:00:00  182.88     174
# 10  102          Adam Dzwigala  1995-09-25 00:00:00  185.42     176
# 11  133       Adam Waszkiewicz  1993-12-06 00:00:00  182.88     174
# 12  136         Adama Francois  1989-11-30 00:00:00  193.04     176
# 13  153         Admir Aganovic  1986-08-25 00:00:00  182.88     176
# 14  154          Admir Mehmedi  1991-03-16 00:00:00  182.88     176
# 15  194                Adriano  1980-01-29 00:00:00  182.88     176
# 16  209           Agon Mehmeti  1989-11-20 00:00:00  182.88     174
# 17  210       Agustin Vuletich  1991-11-03 00:00:00  185.42     174
# 18  221       Ahmed Saied Okka  1984-03-13 00:00:00  185.42     174
# 19  242             Akpo Sodje  1981-01-31 00:00:00  187.96     176
# 20  257            Alan Kardec  1989-01-12 00:00:00  187.96     176
# 21  268          Alassane Plea  1993-03-10 00:00:00  180.34     174
# 22  283          Albert Streit  1980-03-28 00:00:00  180.34     174
# 23  284       Alberto Aquilani  1984-07-07 00:00:00  185.42     174
# 24  285          Alberto Botia  1989-01-27 00:00:00  187.96     176
# 25  293      Alberto Gilardino  1982-07-05 00:00:00  182.88     174
# 26  298       Alberto Luque,21  1978-03-11 00:00:00  182.88     176
# 27  301       Alberto Paloschi  1990-01-04 00:00:00  182.88     176
# 28  313         Albion Avdijaj  1994-01-12 00:00:00  190.50     176
# 29  319          Aleandro Rosi  1987-05-17 00:00:00  182.88     176

# %% [markdown]
# Listar a los Messi de la base de datos de jugadores

# %%
query= """SELECT id, player_name, birthday, height, weight FROM Player WHERE player_name  = 'Messi';"""
players_messi = pd.read_sql(query, conn)
players_messi
# Out:
# Empty DataFrame
# Columns: [id, player_name, birthday, height, weight]
# Index: []

# %% [markdown]
# ##7. Sentencia ORDER BY
# Ordenar el conjunto de resultados en orden ascendente o descendente

# %% [markdown]
# Listar a los equipos y ordenarlos por nombre

# %%
query= """SELECT team_long_name FROM Team ORDER BY team_long_name ASC LIMIT 25;"""

teams_orderby = pd.read_sql(query, conn)
teams_orderby
# Out:
#              team_long_name
# 0      1. FC Kaiserslautern
# 1                1. FC Köln
# 2            1. FC Nürnberg
# 3           1. FSV Mainz 05
# 4                AC Ajaccio
# 5          AC Arles-Avignon
# 6             AC Bellinzona
# 7              ADO Den Haag
# 8                AJ Auxerre
# 9                 AS Monaco
# 10        AS Nancy-Lorraine
# 11         AS Saint-Étienne
# 12                       AZ
# 13                 Aberdeen
# 14     Académica de Coimbra
# 15                     Ajax
# 16                  Amadora
# 17               Angers SCO
# 18              Arka Gdynia
# 19                  Arsenal
# 20              Aston Villa
# 21                 Atalanta
# 22  Athletic Club de Bilbao
# 23          Atlético Madrid
# 24           BSC Young Boys

# %% [markdown]
# Listar la tabla de países en orden descendentE

# %%
query= """SELECT id, name FROM Country ORDER BY name DESC;"""
teams_orderdesc = pd.read_sql(query, conn)
teams_orderdesc
# Out:
#        id         name
# 0   24558  Switzerland
# 1   21518        Spain
# 2   19694     Scotland
# 3   17642     Portugal
# 4   15722       Poland
# 5   13274  Netherlands
# 6   10257        Italy
# 7    7809      Germany
# 8    4769       France
# 9    1729      England
# 10      1      Belgium

# %% [markdown]
#  Listar el id de los 15 jugadores con menos peso

# %%
query = """SELECT id, player_name, weight FROM Player ORDER BY weight ASC;"""
player_weightasc = pd.read_sql(query, conn)
player_weightasc
# Out:
#           id       player_name  weight
# 0       5453        Juan Quero     117
# 1       6853   Mariusz Rybicki     121
# 2      10954   Yohandry Orozco     121
# 3       1480           Caetano     123
# 4       2612  Diego Buonanotte     123
# ...      ...               ...     ...
# 11055   6772  Marcus Hahnemann     220
# 11056   4412    Ishmael Miller     225
# 11057   4884  Jeroen Verhoeven     227
# 11058   5908  Kristof van Hout     243
# 11059  10313         Tim Wiese     243
#
# [11060 rows x 3 columns]

# %% [markdown]
# Listar el id de los 10 jugadores con mayor estatura

# %%
query ="""SELECT id, player_name, height FROM Player ORDER BY height DESC;"""
player_heightdesc = pd.read_sql(query, conn)
player_heightdesc
# Out:
#          id        player_name  height
# 0      5908   Kristof van Hout  208.28
# 1      1301       Bogdan Milic  203.20
# 2      1926  Costel Pantilimon  203.20
# 3      3274       Fejsal Mulic  203.20
# 4      5568      Jurgen Wevers  203.20
# ...     ...                ...     ...
# 11055  8686      Quentin Othon  162.56
# 11056  9441     Samuel Asamoah  162.56
# 11057  2612   Diego Buonanotte  160.02
# 11058  7258       Maxi Moralez  160.02
# 11059  5453         Juan Quero  157.48
#
# [11060 rows x 3 columns]

# %% [markdown]
# Listar el id de los 10 jugadores con mayor estatura y ordenarlos alfabéticamente pero de forma descendente

# %%
query= """SELECT id, player_name, height FROM Player ORDER BY height AND player_name DESC;"""
player_height_name = pd.read_sql(query, conn)
player_height_name
# Out:
#           id          player_name  height
# 0          1   Aaron Appindangoye  182.88
# 1          2      Aaron Cresswell  170.18
# 2          3          Aaron Doran  170.18
# 3          4        Aaron Galindo  182.88
# 4          5         Aaron Hughes  182.88
# ...      ...                  ...     ...
# 11055  11071       Zoumana Camara  182.88
# 11056  11072         Zsolt Laczko  182.88
# 11057  11073            Zsolt Low  180.34
# 11058  11074  Zurab Khizanishvili  185.42
# 11059  11075   Zvjezdan Misimovic  180.34
#
# [11060 rows x 3 columns]

# %% [markdown]
# ##8. Sentencia GROUP BY

# %% [markdown]
# Queremos conocer cuántos equipos tienen cada tipo de velocidad de juego

# %%
query = """SELECT buildUpPlaySpeedClass, COUNT(id)
        FROM Team_Attributes
        GROUP BY buildUpPlaySpeedClass;"""
teams_speed = pd.read_sql(query, conn)
teams_speed
# Out:
#   buildUpPlaySpeedClass  COUNT(id)
# 0              Balanced       1184
# 1                  Fast        172
# 2                  Slow        102

# %% [markdown]
# Queremos conocer cuántos equipos tienen cada clase de juego defensivo

# %%
query = """SELECT defencePressureClass, COUNT(id) FROM Team_Attributes GROUP BY defencePressureClass;"""
teams_defence = pd.read_sql(query, conn)
teams_defence
# Out:
#   defencePressureClass  COUNT(id)
# 0                 Deep        154
# 1                 High         61
# 2               Medium       1243

# %% [markdown]
# Analítica básica de las temporadas

# %%
query = """SELECT season, COUNT(id), COUNT(stage) AS number_of_stages, AVG(home_team_goal) AS avg_home_team_goals, AVG(away_team_goal) AS avg_away_team_goals, SUM(home_team_goal + away_team_goal) AS total_goals FROM Match GROUP BY season;"""

stages_by_season = pd.read_sql(query, conn)
stages_by_season
# Out:
#       season  COUNT(id)  number_of_stages  avg_home_team_goals  \
# 0  2008/2009       3326              3326             1.505412
# 1  2009/2010       3230              3230             1.541176
# 2  2010/2011       3260              3260             1.548466
# 3  2011/2012       3220              3220             1.572671
# 4  2012/2013       3260              3260             1.550000
# 5  2013/2014       3032              3032             1.578826
# 6  2014/2015       3325              3325             1.520301
# 7  2015/2016       3326              3326             1.543897
#
#    avg_away_team_goals  total_goals
# 0             1.101924         8672
# 1             1.131269         8632
# 2             1.135276         8749
# 3             1.143789         8747
# 4             1.222699         9039
# 5             1.187995         8389
# 6             1.155489         8897
# 7             1.210764         9162

# %% [markdown]
# ## 9 Sentencias JOIN
# ###Tipos de JOIN
#
# *   JOIN: mantiene sólo los registros que coinciden con la condición (después del ON) en ambas tablas, y los registros de ambas tablas que no coincidan, no aparecerían en la tabla de resultado.
# *   LEFT JOIN: devuelve todos los registros de la primera tabla (izquierda), y los registros coincidentes de la segunda tabla (derecha). El resultado es NULL del lado derecho, si no hay coincidencia.
# *   RIGHT JOIN: devuelve todos los registros de la segunda tabla (derecha), y los registros coincidentes de la primera tabla (izquierda). El resultado es NULL del lado izquierdo, si no hay coincidencia.
# *   FULL JOIN: devuelve todos los registros cuando hay una coincidencia en los registros de la primera tabla (izquierda) o segunda tabla (derecha). Nota: FULL JOIN puede potencialmente devolver conjuntos de resultados MUY grandes.

# %% [markdown]
# Lista de ligas y su país

# %%
query = """SELECT L.id AS Id_League, L.name AS Nombre_League, C.name AS Pais
        FROM League AS L
        JOIN Country AS C ON C.id = L.country_id;"""

country_leagues = pd.read_sql(query, conn)
country_leagues
# Out:
#     Id_League             Nombre_League         Pais
# 0           1    Belgium Jupiler League      Belgium
# 1        1729    England Premier League      England
# 2        4769            France Ligue 1       France
# 3        7809     Germany 1. Bundesliga      Germany
# 4       10257             Italy Serie A        Italy
# 5       13274    Netherlands Eredivisie  Netherlands
# 6       15722        Poland Ekstraklasa       Poland
# 7       17642  Portugal Liga ZON Sagres     Portugal
# 8       19694   Scotland Premier League     Scotland
# 9       21518           Spain LIGA BBVA        Spain
# 10      24558  Switzerland Super League  Switzerland

# %% [markdown]
# Comparación de cantidad de partidos jugados en cierta temporada de España y Bélgica

# %%
query = """
SELECT
    c.name AS country_name,
    COUNT(*) AS count_matches
FROM Match m
INNER JOIN Country c ON m.country_id = c.id
WHERE season = '2008/2009'
  AND c.name IN ('Spain', 'Belgium')
GROUP BY c.name
ORDER BY count_matches DESC;
"""
country_matches = pd.read_sql(query, conn)
country_matches
# Out:
#   country_name  count_matches
# 0        Spain            380
# 1      Belgium            306

# %% [markdown]
# Lista detallada de juegos

# %%
query = """
SELECT
    m.id,
    c.name AS country_name,
    l.name AS league_name,
    m.season,
    m.stage,
    m.date,
    ht.team_long_name AS home_team,
    at.team_long_name AS away_team,
    m.home_team_goal,
    m.away_team_goal

FROM Match m
INNER JOIN Country c ON m.country_id = c.id
INNER JOIN League l ON m.league_id = l.id
INNER JOIN Team ht ON m.home_team_api_id = ht.team_api_id
INNER JOIN Team at ON m.away_team_api_id = at.team_api_id
WHERE c.name = 'Spain'
ORDER BY m.date ASC
LIMIT 10;
"""
detailed_matches = pd.read_sql(query, conn)
detailed_matches
# Out:
#       id country_name      league_name     season  stage                 date  \
# 0  21518        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-30 00:00:00
# 1  21525        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-30 00:00:00
# 2  21519        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 3  21520        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 4  21521        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 5  21522        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 6  21523        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 7  21524        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 8  21526        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
# 9  21527        Spain  Spain LIGA BBVA  2008/2009      1  2008-08-31 00:00:00
#
#                    home_team        away_team  home_team_goal
# 0                Valencia CF     RCD Mallorca               3  0
# 1               RCD Espanyol  Real Valladolid               1  0
# 2                 CA Osasuna    Villarreal CF               1  1
# 3  RC Deportivo de La Coruña   Real Madrid CF               2  1
# 4                CD Numancia     FC Barcelona               1  0
# 5           Racing Santander       Sevilla FC               1  1
# 6     Real Sporting de Gijón        Getafe CF               1  2
# 7        Real Betis Balompié    RC Recreativo               0  1
# 8    Athletic Club de Bilbao       UD Almería               1  3
# 9            Atlético Madrid        Málaga CF               4  0

# %% [markdown]
# ##10. Sentencia HAVING
# La sentencia HAVING fue añadida a SQL porque la palabra clave WHERE no podía ser usada con funciones agregativas. Entonces, HAVING es como el WHERE para las funciones agregativas.
#
# La sintaxis de HAVING es así:
#
# SELECT column_name(s)
#
# FROM table_name
#
# WHERE condition
#
# GROUP BY column_name(s)
#
# HAVING condition
#
# ORDER BY column_name(s);
#
# HAVING añade otra capa de filtrado a los datos, esta vez sobre el resultado de la tabla después de la agrupación. Muchas veces se utiliza para limpiar la salida.
#
# Función ROUND() para redondear
# En SQLite La función ROUND() se utiliza para redondear un número decimal dado a las posiciones decimales especificadas basándose en un núumero de decimales dado.
#
# La sintaxis, es la siguiente: ROUND( number, decimal_value )
#
#
# *   number: Es el número decimal que necesitamos redondear.
# *   decimal_value: Define el número de decimales a redondear.
#
# Si decimal_value es un número positivo significa que el número se redondea hasta cerca de su valor.
# En caso de que decimal_value se omita o sea negativo, se toma el valor por defecto que es cero (0) y el número se redondeará a cero (0) decimales, pero el número seguirá siendo un valor de punto flotante.

# %% [markdown]
# Análisis de goles por temporada en las ligas de España, Francia e Inglaterr

# %%
query = """SELECT season,
            Country.name AS Country,
            League.name AS League,
            ROUND(AVG(Match.home_team_goal),2) AS avg_local_goals,
            ROUND(AVG(Match.away_team_goal),2) AS avg_visitor_goals,
            SUM(home_team_goal+away_team_goal) AS total_goals
        FROM Match
        JOIN Country ON Country.id = Match.country_id
        JOIN League ON League.id = Match.league_id
        WHERE Country.name IN ('Spain', 'France', 'England')
        GROUP BY season, League
        HAVING avg_local_goals BETWEEN 1.4 AND 1.6 AND avg_visitor_goals BETWEEN 1.2 AND 1.6
        ORDER BY season DESC;"""

goals_by_season = pd.read_sql(query, conn)
goals_by_season
# Out:
#       season  Country                  League  avg_local_goals  \
# 0  2015/2016  England  England Premier League             1.49
# 1  2012/2013  England  England Premier League             1.56
# 2  2011/2012  England  England Premier League             1.59
#
#    avg_visitor_goals  total_goals
# 0               1.21         1026
# 1               1.24         1063
# 2               1.22         1066

# %% [markdown]
# Nos basaremos en ejemplo "Lista detallada de juegos", pero eliminaremos la información del partido y fechas, para comparar las ligas por temporadas

# %%
query=  """
SELECT C.name AS country_name,
L.name AS league_name,
Count(stages) AS Stages,
L.season,
Count(team_long_name) AS numbre_of_teams,
ROUND(AVG(home_team_goal),2) AS avg_local_goals,
ROUND(AVG(away_team_goal),2) AS avg_visitor_goals,
Round(AVG(home_team_goal+away_team_),2) AS avg_goals
Round(AVG(home_team_goal-away_team_),2) AS avg_goals_dif
Sum(home_team_goal+away_team_) AS total_goals

From Match AS M
Join Country On country_id = Match.country_id
Join League On League.id = Match.league_id
Join Team On Team.team_api_id = Match.home_team_api_id,
WHERE Country.name IN ('Spain', 'Germany','Italy', 'France', 'England')
        GROUP BY season, League
        HAVING avg_goals > 2.5
        ORDER BY season;
"""
leages_by_season = pd.read_sql(query, conn)
leages_by_season
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2261         try:
# -> 2262             cur.execute(sql, *args)
#    2263             return cur
#
# OperationalError: near "Round": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-48-f9d14ad8d731> in <cell line: 22>()
#      20         ORDER BY season;
#      21 """
# ---> 22 leages_by_season = pd.read_sql(query, conn)
#      23 leages_by_season
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     652     with pandasSQL_builder(con) as pandas_sql:
#     653         if isinstance(pandas_sql, SQLiteDatabase):
# --> 654             return pandas_sql.read_query(
#     655                 sql,
#     656                 index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2324         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2325     ) -> DataFrame | Iterator[DataFrame]:
# -> 2326         cursor = self.execute(sql, params)
#    2327         columns = [col_desc[0] for col_desc in cursor.description]
#    2328
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2272
#    2273             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2274             raise ex from exc
#    2275
#    2276     @staticmethod
#
# DatabaseError: Execution failed on sql '
# SELECT C.name AS country_name,
# L.name AS league_name,
# Count(stages) AS Stages,
# L.season,
# Count(team_long_name) AS numbre_of_teams,
# ROUND(AVG(home_team_goal),2) AS avg_local_goals,
# ROUND(AVG(away_team_goal),2) AS avg_visitor_goals,
# Round(AVG(home_team_goal+away_team_),2) AS avg_goals
# Round(AVG(home_team_goal-away_team_),2) AS avg_goals_dif
# Sum(home_team_goal+away_team_) AS total_goals
#
# From Match AS M
# Join Country On country_id = Match.country_id
# Join League On League.id = Match.league_id
# Join Team On Team.team_api_id = Match.home_team_api_id,
# WHERE Country.name IN ('Spain', 'Germany','Italy', 'France', 'England')
#         GROUP BY season, League
#         HAVING avg_goals > 2.5
#         ORDER BY season;
# ': near "Round": syntax error
